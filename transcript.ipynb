# %%
# %pip install youtube_transcript_api
# Out:
# Requirement already satisfied: youtube_transcript_api in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.6.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from youtube_transcript_api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->youtube_transcript_api) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
video_id = 'aRcUVhVlSHg'

# %%
YouTubeTranscriptApi.get_transcript(video_id)
# Out:
# [{'text': 'I just dropped off five men and five\nwomen in the middle of the wilderness.',
#   'start': 0.033,
#   'duration': 4.404},
#  {'text': 'And whichever group survives\nthe longest wins that five hundred grand.',
#   'start': 4.437,
#   'duration': 3.737},
#  {'text': 'I give you all three days.', 'start': 8.208, 'duration': 1.034},
#  {'text': 'That money is all ours!', 'start': 9.242, 'duration': 1.468},
#  {'text': 'That is your side of the woods,\nand that is your side of the woods.',
#   'start': 10.71,
#   'duration': 3.304},
#  {'text': 'And you are not at any point\nallowed to cross sides',
#   'start': 14.014,
#   'duration': 2.802},
#  {'text': "or you'll be disqualified.", 'start': 16.816, 'duration': 1.202},
#  {'text': 'You should go start prepping\nfor your first night.',
#   'start': 18.018,
#   'duration': 1.935},
#  {'text': '- We out!\n- May the odds be ever in your favor.',
#   'start': 19.953,
#   'duration': 2.502},
#  {'text': "Men or women, let's see who wins.",
#   'start': 22.455,
#   'duration': 2.536},
#  {'text': "There's no way the girls are beating us.",
#   'start': 24.991,
#   'duration': 1.668},
#  {'text': "They're not five men.", 'start': 26.659, 'duration': 1.802},
#  {'text': '- How do you think the guys are doing?\n- Terrible!',
#   'start': 28.461,
#   'duration': 2.069},
#  {'text': 'They probably stopped by now.', 'start': 30.53, 'duration': 1.235},
#  {'text': "We're not going to survive,\nwe're going to thrive.",
#   'start': 31.798,
#   'duration': 1.568},
#  {'text': "As long as we're good\nat being a little hungry.",
#   'start': 33.4,
#   'duration': 1.568},
#  {'text': "We'll be fine.", 'start': 35.001, 'duration': 0.968},
#  {'text': 'Oh, we got strawberries.', 'start': 36.002, 'duration': 1.001},
#  {'text': 'What?', 'start': 37.037, 'duration': 1.034},
#  {'text': "Anything that's around\nhere is on our food list.",
#   'start': 38.071,
#   'duration': 2.436},
#  {'text': "I'm already seeing a shelter\nin my head.",
#   'start': 40.507,
#   'duration': 2.335},
#  {'text': 'There it is.', 'start': 42.842, 'duration': 0.868},
#  {'text': '- This will be our shelter.\n- Welcome home brothers!',
#   'start': 43.71,
#   'duration': 2.636},
#  {'text': 'And miles away on the other side,',
#   'start': 46.346,
#   'duration': 1.601},
#  {'text': 'the girls found a spot\nto set up their camp.',
#   'start': 47.947,
#   'duration': 1.869},
#  {'text': 'The water looks pretty bad\nright here,',
#   'start': 49.816,
#   'duration': 1.635},
#  {'text': "so I'm hoping we can follow it back",
#   'start': 51.451,
#   'duration': 1.602},
#  {'text': 'and maybe find a clean source\nto gather from.',
#   'start': 53.053,
#   'duration': 2.135},
#  {'text': 'This is nice.', 'start': 55.188, 'duration': 1.201},
#  {'text': 'Yeah, this might be the spot\nyou guys.',
#   'start': 56.389,
#   'duration': 1.635},
#  {'text': 'Things might be going smooth now,',
#   'start': 58.024,
#   'duration': 1.668},
#  {'text': "but this challenge will become the\nmost brutal one that I've ever filmed.",
#   'start': 59.692,
#   'duration': 3.871},
#  {'text': 'If I left now, I would regret it.',
#   'start': 63.563,
#   'duration': 1.969},
#  {'text': "It's so hard out here.", 'start': 65.532, 'duration': 1.568},
#  {'text': 'I just heard some move in there, bro.',
#   'start': 67.1,
#   'duration': 1.501},
#  {'text': "I don't think we're alone out here.",
#   'start': 68.601,
#   'duration': 1.622},
#  {'text': "Okay, let's check what supplies we have.",
#   'start': 70.844,
#   'duration': 1.514},
#  {'text': '- Fruit.\n- Granola.', 'start': 72.383, 'duration': 1.29},
#  {'text': 'Sausage.', 'start': 73.673, 'duration': 0.667},
#  {'text': 'Dude, you got all the meat.', 'start': 74.374, 'duration': 1.334},
#  {'text': 'I also gave each of them\na full water bottle',
#   'start': 75.775,
#   'duration': 1.869},
#  {'text': 'and some key survival gear.', 'start': 77.669, 'duration': 1.368},
#  {'text': "That's not a lot of food.", 'start': 79.081, 'duration': 1.082},
#  {'text': "We're gonna have to figure out how\nlong we want to stretch this.",
#   'start': 80.187,
#   'duration': 1.728},
#  {'text': 'Attention! Can all of you hear me?',
#   'start': 82.015,
#   'duration': 1.868},
#  {'text': "- We hear you loud and clear.\n- We're all here.",
#   'start': 83.883,
#   'duration': 1.001},
#  {'text': "- We hear you loud and clear.\n- We're all here.",
#   'start': 84.884,
#   'duration': 0.534},
#  {'text': "I just want to make sure\nwe're all on the same page",
#   'start': 85.418,
#   'duration': 1.935},
#  {'text': 'on how this challenge works.\nTo make things more interesting.',
#   'start': 87.353,
#   'duration': 2.536},
#  {'text': 'If a person leaves this challenge, they\ncan still get their share of the money.',
#   'start': 89.889,
#   'duration': 3.871},
#  {'text': 'The only thing that matters is\nwhich team has the last player left.',
#   'start': 93.76,
#   'duration': 3.87},
#  {'text': '- What?\n- We were not expecting that.',
#   'start': 97.664,
#   'duration': 2.269},
#  {'text': 'No one ever does.', 'start': 99.933, 'duration': 0.8},
#  {'text': "It's up to each of you to decide\nwhether you stay",
#   'start': 100.733,
#   'duration': 2.57},
#  {'text': 'to help your teammates,\nor leave to save them food.',
#   'start': 103.303,
#   'duration': 2.736},
#  {'text': 'Also, for this entire challenge,\nyou will never know how many men',
#   'start': 106.039,
#   'duration': 3.77},
#  {'text': 'are still left on their side,\nand the men will have no idea',
#   'start': 109.809,
#   'duration': 2.67},
#  {'text': 'how many women are left\non your side.',
#   'start': 112.479,
#   'duration': 1.801},
#  {'text': "It's a game of strategy.\nThis will be fun.",
#   'start': 114.28,
#   'duration': 1.869},
#  {'text': 'That food goes a lot further\nfor like two people than five.',
#   'start': 116.149,
#   'duration': 3.07},
#  {'text': 'Are we really only going to be able\nto sustain 1 or 2 people',
#   'start': 119.219,
#   'duration': 2.736},
#  {'text': 'We’ll cross that bridge when we get there.',
#   'start': 121.988,
#   'duration': 1.168},
#  {'text': 'If anybody does quit,\nI do not hold it against you.',
#   'start': 123.156,
#   'duration': 2.569},
#  {'text': '- I will 100% holding it against you.\n- Yeah. For sure. Come on bro.',
#   'start': 125.725,
#   'duration': 3.203},
#  {'text': 'Hey, after that first week,\nI think its strategy though,',
#   'start': 128.962,
#   'duration': 2.068},
#  {'text': '- We got to strategize.\n- One hundred percent.',
#   'start': 131.097,
#   'duration': 1.135},
#  {'text': "Hey, we're a team bro.", 'start': 132.298, 'duration': 0.968},
#  {'text': "- We're making it.\n- We're staying.",
#   'start': 133.299,
#   'duration': 1.235},
#  {'text': 'Girls rule, boys drool.', 'start': 134.567, 'duration': 1.535},
#  {'text': 'For the rest of the night.', 'start': 137.67, 'duration': 0.968},
#  {'text': 'Both camps began', 'start': 138.638, 'duration': 1.101},
#  {'text': 'constructing their shelters\nto prepare for any upcoming storms,',
#   'start': 139.739,
#   'duration': 3.17},
#  {'text': 'and the guys built theirs\nout of the first twigs they found.',
#   'start': 142.909,
#   'duration': 2.869},
#  {'text': 'We have the whole teepee built\nand everything.',
#   'start': 145.778,
#   'duration': 1.602},
#  {'text': 'The girls are not doing that.', 'start': 147.38, 'duration': 1.502},
#  {'text': 'Actually, they are.', 'start': 148.882, 'duration': 1.001},
#  {'text': "And they're doing it\nway better than the boys.",
#   'start': 149.883,
#   'duration': 2.102},
#  {'text': '- And, up!\n- We got it.', 'start': 151.985, 'duration': 1.501},
#  {'text': "I'm going to try and get a fire prepped.",
#   'start': 153.486,
#   'duration': 1.602},
#  {'text': 'Bet we beat the guys in that.',
#   'start': 156.556,
#   'duration': 1.435},
#  {'text': '- There we go.\n- There we go.',
#   'start': 158.091,
#   'duration': 1.168},
#  {'text': "Let's go.", 'start': 159.259, 'duration': 0.834},
#  {'text': 'What a Freakin start of a journey, boys.',
#   'start': 160.126,
#   'duration': 2.503},
#  {'text': 'Night number one was kind of rough.',
#   'start': 163.263,
#   'duration': 1.668},
#  {'text': 'It took me a long time\nto go to sleep.',
#   'start': 164.931,
#   'duration': 2.169},
#  {'text': 'Good morning.', 'start': 167.1, 'duration': 0.667},
#  {'text': 'We need more walls\nfor the teepee still.',
#   'start': 167.767,
#   'duration': 2.336},
#  {'text': "Let's get making our house.", 'start': 170.103, 'duration': 1.435},
#  {'text': 'I think the girls are doing\nway better than the boys right now.',
#   'start': 171.538,
#   'duration': 1.968},
#  {'text': 'We are going through the woods\nbecause we need water.',
#   'start': 173.506,
#   'duration': 2.936},
#  {'text': 'And to get clean water.', 'start': 176.442, 'duration': 1.168},
#  {'text': 'The boys had to travel miles\nto undrinkable, filthy swamp.',
#   'start': 177.61,
#   'duration': 3.17},
#  {'text': 'I hope the girls have to go\nthrough something like this.',
#   'start': 180.805,
#   'duration': 1.643},
#  {'text': "I'm not going to lie.", 'start': 182.448, 'duration': 0.634},
#  {'text': "You can't see anything\nin this water.",
#   'start': 183.082,
#   'duration': 1.368},
#  {'text': 'I do not want to drink swamp water.',
#   'start': 184.45,
#   'duration': 1.702},
#  {'text': 'Well over a mile and a half.\nTwo mile walk.',
#   'start': 186.152,
#   'duration': 2.302},
#  {'text': "It's day two.", 'start': 188.454, 'duration': 1.202},
#  {'text': 'And after hours of searching,',
#   'start': 189.656,
#   'duration': 1.468},
#  {'text': 'the boys\nfinally found their water source.',
#   'start': 191.124,
#   'duration': 2.002},
#  {'text': 'We made it.', 'start': 193.126, 'duration': 0.5},
#  {'text': 'Finally.', 'start': 193.626, 'duration': 0.834},
#  {'text': 'By day three,', 'start': 194.494, 'duration': 0.901},
#  {'text': 'the women were already\nstrategizing to self eliminate',
#   'start': 195.395,
#   'duration': 2.636},
#  {'text': 'some of their teammates\nto help preserve their food supply.',
#   'start': 198.031,
#   'duration': 2.469},
#  {'text': 'If we as a team want to win this,\ndiving into this,',
#   'start': 200.5,
#   'duration': 3.737},
#  {'text': "it's not sustainable\neven for two people.",
#   'start': 204.27,
#   'duration': 1.835},
#  {'text': 'I would like to have two people here\nat least until the end.',
#   'start': 206.105,
#   'duration': 2.67},
#  {'text': 'I would agree.', 'start': 208.775, 'duration': 0.767},
#  {'text': 'And it was very clear\nto the whole team',
#   'start': 209.542,
#   'duration': 1.869},
#  {'text': 'who those two girls would be.',
#   'start': 211.411,
#   'duration': 1.434},
#  {'text': 'Phaedra and Julia are our survival mommies,\nand so we kind of are at their beck',
#   'start': 212.845,
#   'duration': 4.271},
#  {'text': 'and call to help\nand do whatever we need.',
#   'start': 217.116,
#   'duration': 1.669},
#  {'text': 'The boys, on the other hand,\nhad absolutely no clue whatsoever.',
#   'start': 218.785,
#   'duration': 3.603},
#  {'text': 'We are definitely not rationing it',
#   'start': 222.422,
#   'duration': 1.468},
#  {'text': "like, no, there's no talking\nstrategy amongst us.",
#   'start': 223.89,
#   'duration': 3.103},
#  {'text': 'Five people is a lot of people eating\nof that food stash.',
#   'start': 226.993,
#   'duration': 2.869},
#  {'text': "We can't last to the end\nwith five people.",
#   'start': 229.862,
#   'duration': 2.036},
#  {'text': 'Day four Josh and I were talking\nabout us having to be the providers.',
#   'start': 231.898,
#   'duration': 4.171},
#  {'text': 'While they are the entertainers.',
#   'start': 236.069,
#   'duration': 2.269},
#  {'text': 'TJ and I were carrying the weight.',
#   'start': 238.338,
#   'duration': 2.002},
#  {'text': 'Just been building, building,\nbuilding, building for the team.',
#   'start': 240.34,
#   'duration': 2.569},
#  {'text': "And there's those three still\nsitting around the fire doing nothing.",
#   'start': 242.909,
#   'duration': 3.37},
#  {'text': 'They just want to be served.', 'start': 246.279, 'duration': 1.068},
#  {'text': 'Josh are you gonna tell\nus the food was done?',
#   'start': 247.347,
#   'duration': 2.202},
#  {'text': '- Yeah.\n- When?', 'start': 249.549, 'duration': 1.301},
#  {'text': 'Did you know the food was done?',
#   'start': 251.684,
#   'duration': 1.168},
#  {'text': '- No.\n- I know I’m not the only one!',
#   'start': 252.852,
#   'duration': 1.668},
#  {'text': 'Hey, I thought so, silence.', 'start': 254.52, 'duration': 1.202},
#  {'text': 'By this point,', 'start': 255.722, 'duration': 0.734},
#  {'text': "the boys weren't even a week into the\nchallenge and were already teaming up",
#   'start': 256.456,
#   'duration': 3.837},
#  {'text': 'against one of their own.', 'start': 260.293, 'duration': 0.968},
#  {'text': 'I will directly say to Josh,', 'start': 261.261, 'duration': 1.735},
#  {'text': "it looks like you're\nchillin all day,",
#   'start': 262.996,
#   'duration': 1.735},
#  {'text': "and then we're burning", 'start': 264.731, 'duration': 1.268},
#  {'text': 'Gods amounts of energy day in and day out.',
#   'start': 265.999,
#   'duration': 2.502},
#  {'text': 'And that hurt a lot.', 'start': 268.501, 'duration': 0.667},
#  {'text': "I mean, if anything past burning\nthese calories that he's so tired",
#   'start': 269.168,
#   'duration': 3.003},
#  {'text': 'about doing backflips and showing\noff in front of the camera.',
#   'start': 272.171,
#   'duration': 2.436},
#  {'text': 'So it made me contemplate today',
#   'start': 274.607,
#   'duration': 1.802},
#  {'text': 'whether I really want to do this\nanymore.',
#   'start': 276.409,
#   'duration': 1.668},
#  {'text': 'While tension was making\nsome of the men consider leaving.',
#   'start': 278.077,
#   'duration': 2.703},
#  {'text': 'The girls were ready to do the same,\nbut only as part of the strategy.',
#   'start': 280.78,
#   'duration': 3.303},
#  {'text': "- This food load might have to change.\n- It can't change.",
#   'start': 284.117,
#   'duration': 2.802},
#  {'text': "We're still not\ngetting into rations.",
#   'start': 286.919,
#   'duration': 1.902},
#  {'text': 'It is time to start as a team, sending\npeople home for the goal of winning.',
#   'start': 288.821,
#   'duration': 4.405},
#  {'text': "It can't be more than two people\ntouching the rations.",
#   'start': 293.226,
#   'duration': 3.003},
#  {'text': "So we have as a team decided\nthat it's time for me to go home.",
#   'start': 296.229,
#   'duration': 2.769},
#  {'text': "This is Hannah,\nand I'm ready to leave.",
#   'start': 298.998,
#   'duration': 1.769},
#  {'text': 'We will discreetly evacuate you out\nof the forest without alerting the boys.',
#   'start': 300.767,
#   'duration': 3.97},
#  {'text': "Let's do it with a discreet\nmonster truck.",
#   'start': 304.737,
#   'duration': 2.469},
#  {'text': "We're about to pull up on their camp\nfor the first elimination.",
#   'start': 307.206,
#   'duration': 2.937},
#  {'text': "I'm going to step away\nas a team strategy.",
#   'start': 310.143,
#   'duration': 2.235},
#  {'text': 'It makes sense. More food\nfor the other four.',
#   'start': 312.378,
#   'duration': 2.102},
#  {'text': "Let's get you out of here.", 'start': 314.514, 'duration': 1.201},
#  {'text': 'I want you winning okay?', 'start': 315.715, 'duration': 1.668},
#  {'text': 'You did so good!', 'start': 317.383, 'duration': 1.101},
#  {'text': 'If the women end up winning.', 'start': 318.484, 'duration': 1.268},
#  {'text': "You're the smartest one here.",
#   'start': 319.752,
#   'duration': 1.001},
#  {'text': "You're the first out,\nbut you'll get 100 grand.",
#   'start': 320.753,
#   'duration': 2.336},
#  {'text': 'A lot of people said “look\nI would have just left”.',
#   'start': 323.089,
#   'duration': 1.802},
#  {'text': 'Well, Hannah can consider herself\nlucky because for the next two days,',
#   'start': 324.891,
#   'duration': 3.603},
#  {'text': 'intense rainstorms\nforced both of the teams',
#   'start': 328.494,
#   'duration': 2.636},
#  {'text': 'to stay in their shelters\nand survive solely on their rations.',
#   'start': 331.13,
#   'duration': 3.17},
#  {'text': "We definitely can't live off\nthis food for much longer.",
#   'start': 334.334,
#   'duration': 2.502},
#  {'text': 'So come day ten,\nI decided to throw in a twist.',
#   'start': 336.836,
#   'duration': 2.803},
#  {'text': "And if you've ever seen one\nof my videos, you know what that means.",
#   'start': 339.639,
#   'duration': 2.269},
#  {'text': "It's time for a challenge.", 'start': 341.908, 'duration': 1.168},
#  {'text': 'But to make it even more intense\nin this video, every ten days',
#   'start': 343.076,
#   'duration': 3.703},
#  {'text': 'the boys and girls are going\nto have to face each other.',
#   'start': 346.779,
#   'duration': 2.603},
#  {'text': "And we're gonna kick things off\nby visiting the girls.",
#   'start': 349.382,
#   'duration': 2.069},
#  {'text': "Hi. It's day ten.\nWhat do you think that means?",
#   'start': 352.385,
#   'duration': 2.436},
#  {'text': "You're going to give us some\ngreat news?",
#   'start': 354.821,
#   'duration': 1.434},
#  {'text': 'Depends.', 'start': 356.289, 'duration': 1.034},
#  {'text': 'I need you to pick a leader\nand face one of the boys',
#   'start': 357.323,
#   'duration': 3.07},
#  {'text': 'for a potential prize.', 'start': 360.393, 'duration': 1.168},
#  {'text': "I'll meet you at the bridge\nin an hour, whoever you pick.",
#   'start': 361.561,
#   'duration': 1.768},
#  {'text': 'This is where we take the video\nup a notch.',
#   'start': 363.329,
#   'duration': 2.569},
#  {'text': 'We choose Phaedra.', 'start': 365.898, 'duration': 1.202},
#  {'text': "Let's go see how the boys are doing.",
#   'start': 367.1,
#   'duration': 1.601},
#  {'text': "Welcome to the men's camp.", 'start': 368.701, 'duration': 1.769},
#  {'text': 'You guys look so official.', 'start': 370.47, 'duration': 1.334},
#  {'text': 'I need you guys to elect a leader\nthat in one hour',
#   'start': 371.804,
#   'duration': 3.27},
#  {'text': 'will meet me at the bridge.', 'start': 375.074, 'duration': 1.402},
#  {'text': 'Unanimously, Killer p', 'start': 376.476, 'duration': 1.701},
#  {'text': 'Man, I’m feeling extremely confident.',
#   'start': 378.211,
#   'duration': 1.268},
#  {'text': 'Inside I feel a little scared.',
#   'start': 379.512,
#   'duration': 1.935},
#  {'text': 'Come on in.\nThese walks are so dramatic.',
#   'start': 381.447,
#   'duration': 2.269},
#  {'text': 'Congratulations on surviving\nten days.',
#   'start': 383.716,
#   'duration': 2.102},
#  {'text': "How's it going?", 'start': 385.818, 'duration': 0.801},
#  {'text': 'Really well, actually.', 'start': 386.619, 'duration': 1.268},
#  {'text': 'And remember,', 'start': 387.887, 'duration': 0.701},
#  {'text': 'they have no idea how many people',
#   'start': 388.588,
#   'duration': 1.868},
#  {'text': 'are still left\nfrom the opposing team.',
#   'start': 390.456,
#   'duration': 2.136},
#  {'text': 'How many women do you think\nare still in?',
#   'start': 392.592,
#   'duration': 1.635},
#  {'text': "There's three.", 'start': 394.227, 'duration': 0.934},
#  {'text': "- How many men do you think are left?\n- I'm going to say three too.",
#   'start': 395.194,
#   'duration': 2.469},
#  {'text': 'The funny thing is,\nboth of them are completely wrong',
#   'start': 397.663,
#   'duration': 2.837},
#  {'text': 'and neither will know the truth\nuntil one team wins it all.',
#   'start': 400.5,
#   'duration': 3.303},
#  {'text': 'This challenge is simple.', 'start': 403.836, 'duration': 1.168},
#  {'text': "You're going to take turns\nfiring at that target.",
#   'start': 405.004,
#   'duration': 1.969},
#  {'text': 'And hanging from beneath a target\nis a bag full of perishable food.',
#   'start': 407.006,
#   'duration': 3.704},
#  {'text': "If you hit the target,\nit'll drop it.",
#   'start': 410.743,
#   'duration': 1.669},
#  {'text': 'But if you miss,\nmove it to the other side.',
#   'start': 412.412,
#   'duration': 2.068},
#  {'text': 'She will then get an opportunity\nto try to win it.',
#   'start': 414.48,
#   'duration': 2.603},
#  {'text': "I'm so good at archery.", 'start': 417.083, 'duration': 1.268},
#  {'text': "I'm definitely second\nguessing this decision",
#   'start': 418.351,
#   'duration': 1.902},
#  {'text': 'of sending Patrick and not me.',
#   'start': 420.253,
#   'duration': 1.568},
#  {'text': '- Oh Phaedra is gonna kill it.\n- Absolutely.',
#   'start': 421.821,
#   'duration': 2.369},
#  {'text': 'Whatever it lands on fires first.',
#   'start': 424.19,
#   'duration': 1.635},
#  {'text': 'Not in the water!', 'start': 428.261, 'duration': 1.101},
#  {'text': '- Men!\n- Okay.', 'start': 429.395, 'duration': 1.935},
#  {'text': 'Fire away.', 'start': 431.531, 'duration': 0.667},
#  {'text': "Shot number one.\nWe're out of here.",
#   'start': 432.231,
#   'duration': 1.468},
#  {'text': '- Have you ever shot an arrow before?\n- I have not.',
#   'start': 433.699,
#   'duration': 2.069},
#  {'text': 'Oh. All right.', 'start': 435.768, 'duration': 1.502},
#  {'text': "I feel like I'm\nwatching the Super Bowl.",
#   'start': 437.27,
#   'duration': 1.201},
#  {'text': '- Yeah.\n- First time shooting an arrow?',
#   'start': 438.471,
#   'duration': 1.635},
#  {'text': 'First time shooting an arrow.',
#   'start': 442.442,
#   'duration': 1.234},
#  {'text': '- Bro, what happens?\n- Swing and a miss!',
#   'start': 443.676,
#   'duration': 1.802},
#  {'text': 'Move the target to the other side.',
#   'start': 445.478,
#   'duration': 1.702},
#  {'text': "Let's see if the women's\nteam can make it.",
#   'start': 447.18,
#   'duration': 1.301},
#  {'text': "Whoa! She's taking the jacket off.",
#   'start': 448.481,
#   'duration': 1.969},
#  {'text': "Oh, it's go time.", 'start': 450.45, 'duration': 2.035},
#  {'text': 'Phaedra, your team desperately\nneeds those rations.',
#   'start': 452.485,
#   'duration': 2.97},
#  {'text': 'Will you be the one to bring them\nhome?',
#   'start': 455.455,
#   'duration': 2.569},
#  {'text': 'She got it!', 'start': 462.462, 'duration': 1.735},
#  {'text': "- Yeah!\n- Let's go!", 'start': 464.23, 'duration': 1.568},
#  {'text': 'No way!', 'start': 466.232, 'duration': 1.168},
#  {'text': 'Dude, that was like watching\nthe Hunger Games.',
#   'start': 467.4,
#   'duration': 1.635},
#  {'text': "All right, let's go grab it.", 'start': 470.97, 'duration': 1.568},
#  {'text': '- Cheers to victory!\n- Cheers!',
#   'start': 474.774,
#   'duration': 3.103},
#  {'text': 'Cut to a shot of the boys.', 'start': 478.044, 'duration': 1.134},
#  {'text': "They're struggling.", 'start': 479.212, 'duration': 0.7},
#  {'text': "Let's go, let's go.", 'start': 479.946, 'duration': 1.701},
#  {'text': "So y'all also need to\neat a lot and quickly.",
#   'start': 481.647,
#   'duration': 2.002},
#  {'text': "I've noticed you keep saying y'all.",
#   'start': 483.649,
#   'duration': 1.302},
#  {'text': 'So.', 'start': 486.185, 'duration': 1.001},
#  {'text': 'Wait what?', 'start': 487.22, 'duration': 0.667},
#  {'text': 'We had to dip into our rations\nafter the rain.',
#   'start': 487.887,
#   'duration': 2.069},
#  {'text': 'And look at this.\nThis is primarily perishable.',
#   'start': 489.956,
#   'duration': 2.002},
#  {'text': "So although it adds for a while,\nit's not going to add long term.",
#   'start': 491.958,
#   'duration': 3.036},
#  {'text': 'And so we had the conversation\nI would go.',
#   'start': 495.027,
#   'duration': 1.869},
#  {'text': '- You think about leaving right now.\n- Yes.',
#   'start': 496.896,
#   'duration': 1.635},
#  {'text': "Conveniently I'm already here",
#   'start': 498.531,
#   'duration': 1.034},
#  {'text': '- if you just want to hitch a ride back?\n- Yeah. Now.',
#   'start': 499.565,
#   'duration': 1.869},
#  {'text': 'And so with a toast of Feastables\nand hugs to say goodbye.',
#   'start': 501.434,
#   'duration': 2.736},
#  {'text': 'Bye Divas!', 'start': 504.203, 'duration': 0.801},
#  {'text': "We'll see you on the outside.",
#   'start': 505.037,
#   'duration': 1.335},
#  {'text': "The women's team\nwas down to just three survivors,",
#   'start': 506.372,
#   'duration': 2.703},
#  {'text': "while the men's team\nstill had all five.",
#   'start': 509.075,
#   'duration': 2.002},
#  {'text': 'I know we can win this\nentire challenge for her.',
#   'start': 511.077,
#   'duration': 2.102},
#  {'text': '- I do too.\n- And Hannah.', 'start': 513.212, 'duration': 1.001},
#  {'text': 'With plenty of food and one\nless person to split it with.',
#   'start': 514.247,
#   'duration': 2.769},
#  {'text': 'The girls morale was through\nthe roof.',
#   'start': 517.016,
#   'duration': 1.969},
#  {'text': "I'm feeling really good,\nreally optimistic.",
#   'start': 518.985,
#   'duration': 1.902},
#  {'text': "We've been really pushing ourselves\nhard.",
#   'start': 520.887,
#   'duration': 1.935},
#  {'text': 'So to have\nthis meal is going to mean a lot.',
#   'start': 522.822,
#   'duration': 2.102},
#  {'text': 'Cheers, guys.', 'start': 524.924, 'duration': 1.134},
#  {'text': 'Delicious.', 'start': 526.592, 'duration': 1.001},
#  {'text': 'However, losing the challenge\ntook a real toll on TJ.',
#   'start': 527.593,
#   'duration': 3.337},
#  {'text': "I'm beating myself up pretty badly\nabout the archery competition.",
#   'start': 531.197,
#   'duration': 3.47},
#  {'text': 'Everyone thought\nit should have been me. Unanimously.',
#   'start': 534.667,
#   'duration': 2.669},
#  {'text': '- Killer P.\n- Killer P!', 'start': 537.336, 'duration': 1.835},
#  {'text': 'I should have\nstepped up when I had the chance.',
#   'start': 539.205,
#   'duration': 2.703},
#  {'text': 'When I was sitting on that chair\nand I saw the bows and arrows.',
#   'start': 541.941,
#   'duration': 3.07},
#  {'text': 'I just thought', 'start': 546.012, 'duration': 0.934},
#  {'text': 'it should have been me.', 'start': 547.747, 'duration': 1.168},
#  {'text': 'The next challenge will be me.',
#   'start': 549.415,
#   'duration': 1.702},
#  {'text': 'The girls enjoyed their abundance\nof food for the next few days.',
#   'start': 551.117,
#   'duration': 2.869},
#  {'text': 'Cheers.', 'start': 553.986, 'duration': 0.801},
#  {'text': 'The boys unfortunately\nhad to still catch their fish.',
#   'start': 554.787,
#   'duration': 3.17},
#  {'text': "Let's go babe.", 'start': 557.99, 'duration': 0.935},
#  {'text': 'No.', 'start': 560.993, 'duration': 0.935},
#  {'text': 'No way.', 'start': 564.263, 'duration': 2.569},
#  {'text': 'With the rations running dangerously\nlow at this point,',
#   'start': 567.033,
#   'duration': 2.602},
#  {'text': 'the boys team was starting to become\nhopeless.',
#   'start': 569.635,
#   'duration': 2.136},
#  {'text': "Bro Cam, I'm so glad\nthat I got you here, bro.",
#   'start': 571.771,
#   'duration': 2.669},
#  {'text': 'I know I may seem sluggish,\nand stuff, but this is all mental.',
#   'start': 574.44,
#   'duration': 2.97},
#  {'text': 'Like I have nothing in me.', 'start': 577.41, 'duration': 1.201},
#  {'text': 'The pressure had really started\nto get to Cameron,',
#   'start': 578.611,
#   'duration': 2.369},
#  {'text': 'and while Sami tried\nto lift his spirits a little.',
#   'start': 580.98,
#   'duration': 2.102},
#  {'text': 'But the morning of day 13,\nhe had already made up his mind.',
#   'start': 583.082,
#   'duration': 2.87},
#  {'text': 'The sleep deprivation has taken its toll.',
#   'start': 585.952,
#   'duration': 2.902},
#  {'text': "- I just hit my breaking point.\n- I'm proud of you, bro.",
#   'start': 588.854,
#   'duration': 2.269},
#  {'text': 'Hold it down man.', 'start': 591.123, 'duration': 1.302},
#  {'text': '- I appreciate the journey, man.\n- Bye Cam!',
#   'start': 592.425,
#   'duration': 1.835},
#  {'text': 'That was a big bummer.', 'start': 594.26, 'duration': 1.034},
#  {'text': "- Losing Cam today.\n- How's today for a dark day?",
#   'start': 595.294,
#   'duration': 2.77},
#  {'text': "But the boys weren't\nthe only ones taking a loss.",
#   'start': 598.064,
#   'duration': 2.302},
#  {'text': "Today is Talia's day.", 'start': 600.366, 'duration': 2.336},
#  {'text': "We're going to miss her very much.",
#   'start': 602.702,
#   'duration': 1.601},
#  {'text': 'We are.', 'start': 604.303, 'duration': 1.235},
#  {'text': 'While the girls were leaving strategically\nwith half $1 million in mind,',
#   'start': 605.538,
#   'duration': 3.354},
#  {'text': 'the boys, on the other hand,\nwere leaving from the difficulties.',
#   'start': 608.917,
#   'duration': 2.46},
#  {'text': "I'm so defeated.", 'start': 611.377, 'duration': 1.535},
#  {'text': "I'm grateful for this. It's just.",
#   'start': 612.912,
#   'duration': 2.369},
#  {'text': 'This is freakin tough.', 'start': 615.281, 'duration': 1.168},
#  {'text': 'Just had a break down, bro.', 'start': 616.482, 'duration': 1.235},
#  {'text': 'Do you think you can make it\nto the next challenge?',
#   'start': 617.75,
#   'duration': 1.835},
#  {'text': "Oh, no.\nIt's about to break me bro like.",
#   'start': 619.61,
#   'duration': 3.337},
#  {'text': 'Alright bro.', 'start': 623.189, 'duration': 0.969},
#  {'text': 'Big Hug', 'start': 624.657, 'duration': 0.934},
#  {'text': 'So after giving some extra help\nupgrading their shelter,',
#   'start': 625.591,
#   'duration': 2.569},
#  {'text': 'the boys went to bed and made\nthe radio call in the morning.',
#   'start': 628.16,
#   'duration': 2.536},
#  {'text': 'What up boys?', 'start': 631.397, 'duration': 1.034},
#  {'text': 'I got a message on the walkie.',
#   'start': 632.431,
#   'duration': 1.702},
#  {'text': "It's going to have to be\nmine to explain, Jimmy.",
#   'start': 634.133,
#   'duration': 1.768},
#  {'text': "I'm not going to be the big macho\nman and say this isn't hard.",
#   'start': 635.901,
#   'duration': 2.703},
#  {'text': "All right, everyone, let's\nwalk him out of the challenge. Come on.",
#   'start': 638.604,
#   'duration': 2.636},
#  {'text': 'Leaving the boys camp\nfor the last time.',
#   'start': 641.273,
#   'duration': 1.969},
#  {'text': '- Sami, give the guys a parting gift.\n- You want a T-shirt?',
#   'start': 643.242,
#   'duration': 2.269},
#  {'text': "- I'll take a T-shirt.\n- The literal clothes on his back.",
#   'start': 645.511,
#   'duration': 2.803},
#  {'text': "Let's get those shorts", 'start': 648.314, 'duration': 0.6},
#  {'text': "Now that you've taken everything\nfrom this man, is he free to go?",
#   'start': 648.914,
#   'duration': 3.404},
#  {'text': "He's free to go.", 'start': 652.351, 'duration': 0.734},
#  {'text': 'He is now in the Sherpa, which means\nhe is officially eliminated.',
#   'start': 653.085,
#   'duration': 2.903},
#  {'text': 'Karl, get him out of here!', 'start': 655.988, 'duration': 1.468},
#  {'text': "Now we're down to three. Is\nthe trend going to continue?",
#   'start': 657.456,
#   'duration': 1.802},
#  {'text': "Two days from now,\nwe're going to be a one.",
#   'start': 659.258,
#   'duration': 1.402},
#  {'text': 'Absolutely not.', 'start': 660.66, 'duration': 0.633},
#  {'text': 'Just two weeks into the challenge,\nwe had already lost half the players',
#   'start': 661.293,
#   'duration': 3.871},
#  {'text': 'and things were only getting worse.',
#   'start': 665.164,
#   'duration': 1.902},
#  {'text': 'I looked at that truck', 'start': 667.066, 'duration': 1.068},
#  {'text': 'that picked him up\nand my first thought was jealousy.',
#   'start': 668.134,
#   'duration': 3.47},
#  {'text': "I don't know if I can make it to\nthe end.",
#   'start': 671.971,
#   'duration': 1.201},
#  {'text': 'With Josh already on the verge of quitting.',
#   'start': 673.172,
#   'duration': 2.236},
#  {'text': 'Things got even worse\nas a massive storm rolled in.',
#   'start': 675.408,
#   'duration': 3.436},
#  {'text': "It's raining right here.", 'start': 681.013, 'duration': 1.068},
#  {'text': 'Unlike the girls who could sleep\nsoundly in their well-built shelter',
#   'start': 682.081,
#   'duration': 3.236},
#  {'text': 'back at the boys camp,', 'start': 685.351, 'duration': 1.168},
#  {'text': 'their home was not equipped\nto handle all of the rain.',
#   'start': 686.519,
#   'duration': 3.003},
#  {'text': 'This is not how I want this to end.',
#   'start': 689.722,
#   'duration': 1.868},
#  {'text': 'The torrential downpours\ncontinued for the next two days.',
#   'start': 691.59,
#   'duration': 3.571},
#  {'text': 'My raincoat had drenched through\nand my whole belly',
#   'start': 695.327,
#   'duration': 2.87},
#  {'text': 'was soaking wet in my waders\nand my pants were soaking wet.',
#   'start': 698.197,
#   'duration': 3.136},
#  {'text': 'I was like, ready to quit.', 'start': 701.367, 'duration': 2.235},
#  {'text': 'The rain has finally cleared up\nand',
#   'start': 703.602,
#   'duration': 3.304},
#  {'text': 'Mama Phaedra is making us\nsome little breakfast this morning.',
#   'start': 706.906,
#   'duration': 4.237},
#  {'text': "I've got a little beef stew.\nIt's delicious.",
#   'start': 711.21,
#   'duration': 2.002},
#  {'text': "- I bet the boys are enjoying a happy meal.\n- I bet they're not.",
#   'start': 713.212,
#   'duration': 3.036},
#  {'text': 'Bad news, I ran into my worst enemy.',
#   'start': 716.248,
#   'duration': 2.636},
#  {'text': 'Poison ivy.', 'start': 718.884, 'duration': 0.801},
#  {'text': "It's spreading everywhere\nand unbearable painful.",
#   'start': 719.685,
#   'duration': 2.936},
#  {'text': 'And I started wondering\nif my time here is coming up.',
#   'start': 722.621,
#   'duration': 2.503},
#  {'text': "We're in a better\nspot than the guys.",
#   'start': 726.759,
#   'duration': 1.969},
#  {'text': 'Has to be, right?', 'start': 728.728, 'duration': 0.8},
#  {'text': 'Not a lot of people can take this\nfor a long amount of time.',
#   'start': 729.528,
#   'duration': 3.003},
#  {'text': 'Hey, guys, we need to talk.', 'start': 732.765, 'duration': 2.302},
#  {'text': 'The things I wanted to do,\nI definitely did.',
#   'start': 735.768,
#   'duration': 2.069},
#  {'text': 'And at some point\nthere is just the need to get out.',
#   'start': 737.837,
#   'duration': 2.602},
#  {'text': 'The selfish\npart of me says you quit.',
#   'start': 740.439,
#   'duration': 2.002},
#  {'text': 'I get a bigger meal.', 'start': 742.441, 'duration': 1.135},
#  {'text': "Hey, this is Josh at men's camp.",
#   'start': 746.612,
#   'duration': 2.069},
#  {'text': 'I think I am ready to go today.',
#   'start': 748.681,
#   'duration': 2.903},
#  {'text': 'And just like that, Josh was out.',
#   'start': 751.584,
#   'duration': 2.335},
#  {'text': "- Josh, hop on in.\n- Let's go, Karl!",
#   'start': 754.653,
#   'duration': 2.403},
#  {'text': "Let's hit the road.", 'start': 757.089, 'duration': 0.968},
#  {'text': "I'm gonna say this like, honestly, I\nbelieve 100% we just got stronger.",
#   'start': 758.057,
#   'duration': 3.27},
#  {'text': 'We have enough food to last us\nas long as possible,',
#   'start': 761.327,
#   'duration': 2.836},
#  {'text': 'plus win all the challenges.', 'start': 764.163, 'duration': 1.635},
#  {'text': "That's a pretty bold statement.",
#   'start': 765.831,
#   'duration': 1.268},
#  {'text': "So let's put that claim to the test.",
#   'start': 767.133,
#   'duration': 2.002},
#  {'text': "- What day is it, Chandler?\n- It's Friday.",
#   'start': 769.135,
#   'duration': 1.768},
#  {'text': "It's day 20.", 'start': 772.505, 'duration': 0.734},
#  {'text': "Which means it's time for our second\nchallenge.",
#   'start': 773.272,
#   'duration': 2.936},
#  {'text': 'Alert! Alert!', 'start': 776.208, 'duration': 0.768},
#  {'text': 'Pick a captain\nand send them to the bridge.',
#   'start': 776.976,
#   'duration': 2.602},
#  {'text': 'Easy work.', 'start': 779.578, 'duration': 0.935},
#  {'text': "All right. I'll see you in a minute.\nOkay. Sounds good.",
#   'start': 780.513,
#   'duration': 2.035},
#  {'text': "I'm going to show her that\nno matter what, she will never win.",
#   'start': 782.548,
#   'duration': 2.803},
#  {'text': "Since both of you didn't come\nlast time, I need to make it clear.",
#   'start': 785.351,
#   'duration': 3.036},
#  {'text': "You step across the middle.\nYou're eliminated.",
#   'start': 788.387,
#   'duration': 2.169},
#  {'text': "which may affect your team's\nchances of winning 500,000 dollars.",
#   'start': 790.571,
#   'duration': 3.73},
#  {'text': 'Chandler, can you give me\nsomething to mark the middle?',
#   'start': 794.326,
#   'duration': 1.695},
#  {'text': "- It's okay. We'll put it back.\n- Yeah. There you go.",
#   'start': 796.562,
#   'duration': 2.202},
#  {'text': '- Hello.\n- Hi.', 'start': 798.764, 'duration': 1.101},
#  {'text': '- Nice to meet you.\n- You too.',
#   'start': 799.899,
#   'duration': 1.468},
#  {'text': 'My team and I are offering you.',
#   'start': 801.367,
#   'duration': 1.535},
#  {'text': "And whoever's still at camp $50,000\nif your team quits right now.",
#   'start': 802.902,
#   'duration': 3.937},
#  {'text': 'Sounds like you might be scared\nthat you might not make it to the 500 K.',
#   'start': 807.373,
#   'duration': 3.47},
#  {'text': 'Anyone else feel the tension here?',
#   'start': 810.843,
#   'duration': 1.768},
#  {'text': "We'll see in day 33\nwhen it's all over.",
#   'start': 812.611,
#   'duration': 3.07},
#  {'text': 'You’re only giving yourself till day 33?',
#   'start': 815.714,
#   'duration': 1.702},
#  {'text': 'Giving you till day 33.', 'start': 817.416, 'duration': 2.136},
#  {'text': 'You guys are being as nice\nas possible.',
#   'start': 820.219,
#   'duration': 1.535},
#  {'text': 'Also talking so much smack\nat the same time.',
#   'start': 821.754,
#   'duration': 2.769},
#  {'text': "Let's bring it together.", 'start': 824.523, 'duration': 0.934},
#  {'text': 'So, because the storms\nare decimating',
#   'start': 825.457,
#   'duration': 1.936},
#  {'text': 'your shelters in this challenge,',
#   'start': 827.393,
#   'duration': 1.368},
#  {'text': "you're gonna be competing\nfor your own ginormous tent.",
#   'start': 828.761,
#   'duration': 2.502},
#  {'text': 'This thing is bug proof. Waterproof.',
#   'start': 831.263,
#   'duration': 2.336},
#  {'text': "Hurricane season's coming\nin, so this would be clutch.",
#   'start': 833.599,
#   'duration': 2.436},
#  {'text': 'Would you want something like this?',
#   'start': 836.035,
#   'duration': 1.168},
#  {'text': "I mean, I'll take it,", 'start': 837.203, 'duration': 0.9},
#  {'text': "but if the guys get this taste\nof comfort, maybe they'll leave.",
#   'start': 838.103,
#   'duration': 3.037},
#  {'text': '- Or it can make them last longer.\n- Doubt it.',
#   'start': 841.173,
#   'duration': 2.036},
#  {'text': 'Oh, this is very nice.', 'start': 843.209, 'duration': 1.401},
#  {'text': "It's decision time.", 'start': 844.61, 'duration': 1.602},
#  {'text': 'So this is different than the last\nchallenge because both your teams',
#   'start': 846.212,
#   'duration': 3.903},
#  {'text': 'could win a tent.', 'start': 850.216, 'duration': 1.034},
#  {'text': "I'm going to be in that tent.", 'start': 851.25, 'duration': 1.168},
#  {'text': 'It would sit really nicely right there.',
#   'start': 852.418,
#   'duration': 2.135},
#  {'text': 'All you have to do...', 'start': 854.553, 'duration': 1.201},
#  {'text': 'is eliminate yourself.', 'start': 856.422, 'duration': 1.001},
#  {'text': "If Julia does take this, we won't\nhave one more night together.",
#   'start': 859.792,
#   'duration': 3.27},
#  {'text': "That'll be hard.", 'start': 863.062, 'duration': 0.834},
#  {'text': 'Since the women won\nthe first challenge.',
#   'start': 863.896,
#   'duration': 2.169},
#  {'text': '- I need you to make your decision first.\n- No, come on, Julia.',
#   'start': 866.065,
#   'duration': 2.669},
#  {'text': 'Do you want to eliminate yourself\nso your team can have that tent?',
#   'start': 868.767,
#   'duration': 3.304},
#  {'text': "I'm going to take the tent.", 'start': 875.441, 'duration': 1.134},
#  {'text': 'Okay.', 'start': 877.509, 'duration': 1.035},
#  {'text': 'So, it looks like, I am\nnow officially by myself.',
#   'start': 880.012,
#   'duration': 2.97},
#  {'text': "I honestly can't believe\nyou took that.",
#   'start': 883.916,
#   'duration': 1.435},
#  {'text': "Now it's your turn.\nWhich is more important?",
#   'start': 885.351,
#   'duration': 2.569},
#  {'text': 'You or that tent?', 'start': 887.92, 'duration': 2.169},
#  {'text': 'All right.', 'start': 898.464, 'duration': 0.867},
#  {'text': 'My team.', 'start': 899.365, 'duration': 0.867},
#  {'text': '- Thanks for coming out.\n- Thank you.',
#   'start': 900.232,
#   'duration': 1.735},
#  {'text': 'That was crazy.', 'start': 902.034, 'duration': 1.001},
#  {'text': 'Wait wait wait wait wait wait.',
#   'start': 903.068,
#   'duration': 2.536},
#  {'text': 'I think it would really be huge',
#   'start': 905.604,
#   'duration': 1.468},
#  {'text': 'for the overall strategy\nand the win, but,',
#   'start': 907.072,
#   'duration': 2.97},
#  {'text': 'I thought I was actually going to get\na chance to give her a hug goodbye.',
#   'start': 910.609,
#   'duration': 2.536},
#  {'text': "This isn't 100% rain proof. That\ncould really end the competition.",
#   'start': 914.113,
#   'duration': 4.437},
#  {'text': 'My whole mood has just changed.',
#   'start': 918.584,
#   'duration': 1.802},
#  {'text': 'Back at the bridge,', 'start': 920.419, 'duration': 1.001},
#  {'text': 'while Phaedra was gathering her\nnew tent,',
#   'start': 921.42,
#   'duration': 2.035},
#  {'text': 'TJ secretly\nstayed behind to investigate.',
#   'start': 923.455,
#   'duration': 2.503},
#  {'text': 'Wait. No way.', 'start': 925.991, 'duration': 1.435},
#  {'text': 'And what he found was like striking\ngold.',
#   'start': 927.426,
#   'duration': 2.469},
#  {'text': "It's weird to send only one\nperson to pick up that tent.",
#   'start': 929.895,
#   'duration': 3.037},
#  {'text': "Now I know there's only one\nwoman left.",
#   'start': 932.932,
#   'duration': 2.736},
#  {'text': 'She will not outlast the two of us.',
#   'start': 935.668,
#   'duration': 2.736},
#  {'text': 'I got to tell Pat. Patrick,\nare you awake?',
#   'start': 938.404,
#   'duration': 2.402},
#  {'text': "I spied on them,\nand it's one person left.",
#   'start': 940.806,
#   'duration': 2.903},
#  {'text': 'The person that you went\nagainst on that first challenge.',
#   'start': 943.709,
#   'duration': 2.669},
#  {'text': 'We have two, less food, less shelter.',
#   'start': 946.378,
#   'duration': 2.903},
#  {'text': 'Now that you say like that,', 'start': 949.315, 'duration': 1.101},
#  {'text': 'I feel like\nI made the wrong decision.',
#   'start': 950.416,
#   'duration': 1.401},
#  {'text': 'Would\nyou have preferred the tent or me?',
#   'start': 951.817,
#   'duration': 3.003},
#  {'text': 'The tent.', 'start': 955.12, 'duration': 0.701},
#  {'text': 'Unfortunately for TJ,', 'start': 956.488, 'duration': 1.435},
#  {'text': 'the Intel he gathered at the bridge\nseemed to only make matters',
#   'start': 957.923,
#   'duration': 2.97},
#  {'text': 'worse for the boys.', 'start': 960.893, 'duration': 1.068},
#  {'text': 'He turned down dry shelter to come back.',
#   'start': 961.961,
#   'duration': 2.435},
#  {'text': 'What kind of brother\nwould do that? TJ',
#   'start': 964.396,
#   'duration': 2.069},
#  {'text': 'If he would’ve took the tent,\nit would have sealed the deal',
#   'start': 966.465,
#   'duration': 1.702},
#  {'text': 'Because we all know shelter\nis everything.',
#   'start': 968.167,
#   'duration': 2.669},
#  {'text': 'And at the girls camp, Phaedra\nwas officially carrying the team,',
#   'start': 970.836,
#   'duration': 3.103},
#  {'text': 'setting up her brand new tent\nin just a few hours.',
#   'start': 973.939,
#   'duration': 2.636},
#  {'text': 'Look at that.', 'start': 976.575, 'duration': 1.368},
#  {'text': "It's awesome.", 'start': 977.943, 'duration': 0.934},
#  {'text': "Just in case people are wondering\nwho's going to win this.",
#   'start': 978.877,
#   'duration': 2.636},
#  {'text': "It's nice and cool in here.", 'start': 981.513, 'duration': 1.769},
#  {'text': 'No bugs.', 'start': 983.282, 'duration': 1.201},
#  {'text': 'There is more room than I know\nwhat to do with in here.',
#   'start': 984.483,
#   'duration': 2.736},
#  {'text': 'While Phaedra had more room,', 'start': 987.383, 'duration': 1.294},
#  {'text': 'the boys realized that having each\nother was the most valuable thing',
#   'start': 988.702,
#   'duration': 3.002},
#  {'text': 'if they wanted to win their\nteam half a million dollars.',
#   'start': 991.731,
#   'duration': 2.605},
#  {'text': "You may have that tent,\nbut you're all alone.",
#   'start': 994.36,
#   'duration': 2.502},
#  {'text': 'Us here at the guys camp,\nwe still got two',
#   'start': 996.862,
#   'duration': 2.002},
#  {'text': 'so we could always be socializing.',
#   'start': 998.864,
#   'duration': 1.802},
#  {'text': "And by challenge three,\nshe's going to want to leave.",
#   'start': 1000.666,
#   'duration': 2.336},
#  {'text': 'For sure, bro.', 'start': 1003.035, 'duration': 1.535},
#  {'text': 'It was a pleasure\nbeing around Julia.',
#   'start': 1004.57,
#   'duration': 2.068},
#  {'text': 'Having such a lovely human\nto interact with.',
#   'start': 1006.638,
#   'duration': 3.437},
#  {'text': 'Got me spoiled, honestly.', 'start': 1010.175, 'duration': 1.335},
#  {'text': 'The boys seem to have much more\nthan just each other too.',
#   'start': 1011.51,
#   'duration': 2.469},
#  {'text': 'About to go crawdad hunting.\nThis is where killer Patt comes in.',
#   'start': 1014.013,
#   'duration': 3.336},
#  {'text': 'Need to get some food.', 'start': 1017.483, 'duration': 1.101},
#  {'text': 'Living off the land was going much\nbetter than I expected.',
#   'start': 1018.584,
#   'duration': 2.602},
#  {'text': "There we go, and that's\nsnapping turtle right there.",
#   'start': 1021.186,
#   'duration': 2.403},
#  {'text': 'But while the boys are finally\nthriving,',
#   'start': 1023.589,
#   'duration': 1.802},
#  {'text': 'Phaedra has found herself\nin a dark place.',
#   'start': 1025.391,
#   'duration': 2.068},
#  {'text': 'I do miss having\nsome physical contact',
#   'start': 1027.459,
#   'duration': 3.337},
#  {'text': 'with people and like being able\nto give somebody a hug,',
#   'start': 1030.796,
#   'duration': 3.27},
#  {'text': 'or just like even a handshake\nor a high five would do.',
#   'start': 1034.066,
#   'duration': 4.604},
#  {'text': 'How about a high five?', 'start': 1041.34, 'duration': 1.234},
#  {'text': 'At this point,\nPhaedra literally began',
#   'start': 1043.909,
#   'duration': 2.002},
#  {'text': 'talking to herself\nout of loneliness.',
#   'start': 1045.944,
#   'duration': 1.869},
#  {'text': "However, the boy's bond\nwas continuing to grow.",
#   'start': 1047.813,
#   'duration': 2.569},
#  {'text': "Dang, dude, that's as big as you.",
#   'start': 1050.382,
#   'duration': 2.67},
#  {'text': 'Look at the size of that thing.',
#   'start': 1053.052,
#   'duration': 1.768},
#  {'text': "Dude, that's literally 5.5ft long.",
#   'start': 1054.82,
#   'duration': 2.336},
#  {'text': 'Sorry, six foot five.', 'start': 1057.556, 'duration': 1.535},
#  {'text': "I'm so excited for Challenge Day\nright now.",
#   'start': 1059.124,
#   'duration': 1.969},
#  {'text': "I'm hoping\nthat we just go ahead and win.",
#   'start': 1061.093,
#   'duration': 2.202},
#  {'text': "I'm ready to go home to my family.\nI'm ready for this to be over.",
#   'start': 1063.295,
#   'duration': 2.803},
#  {'text': "We're going to see how challenge\nthree goes.",
#   'start': 1066.098,
#   'duration': 1.501},
#  {'text': "With TJ and Patrick's bond\nhaving grown stronger than ever.",
#   'start': 1067.599,
#   'duration': 2.736},
#  {'text': 'I knew exactly how to test them\non the day 30 challenge.',
#   'start': 1070.335,
#   'duration': 2.97},
#  {'text': 'Are you going to be the captain?',
#   'start': 1073.305,
#   'duration': 1.168},
#  {'text': 'I was asking around,\nbut nobody else was here.',
#   'start': 1074.473,
#   'duration': 3.003},
#  {'text': "- By default, I'm the captain.\n- Okay.",
#   'start': 1077.676,
#   'duration': 2.269},
#  {'text': 'You did day ten.', 'start': 1079.945, 'duration': 1.168},
#  {'text': 'You did day 20.', 'start': 1081.113, 'duration': 1.201},
#  {'text': "Who's going to be the day 30 captain?",
#   'start': 1082.314,
#   'duration': 1.935},
#  {'text': '- Patrick.\n- Back to back.', 'start': 1084.249, 'duration': 1.735},
#  {'text': 'Lets go.', 'start': 1085.984, 'duration': 1.235},
#  {'text': 'Go get that dub.', 'start': 1087.252, 'duration': 1.168},
#  {'text': "All right, this time we've painted\na line instead of using a plant.",
#   'start': 1088.42,
#   'duration': 2.87},
#  {'text': 'Been a while\nsince you saw each other.',
#   'start': 1091.29,
#   'duration': 1.501},
#  {'text': "I'm really surprised to see you\nhere, actually.",
#   'start': 1092.791,
#   'duration': 2.336},
#  {'text': 'Yeah.', 'start': 1096.328, 'duration': 0.634},
#  {'text': '- Are you two ready to hear the challenge?\n- Yes.',
#   'start': 1096.962,
#   'duration': 1.802},
#  {'text': "- Yes, sir.\n- Here's the deal.",
#   'start': 1098.764,
#   'duration': 1.535},
#  {'text': 'We have the families\nof every single contestant',
#   'start': 1100.299,
#   'duration': 2.936},
#  {'text': 'still in this challenge\non the other side of the woods.',
#   'start': 1103.235,
#   'duration': 2.336},
#  {'text': 'And you guys have a choice to make.',
# ...
#  {'text': 'Phaedra’s not worried about food at all.',
#   'start': 1499.064,
#   'duration': 2.068},
#  {'text': 'They say how much gas you have\nin the tank, and truly, my answer',
#   'start': 1501.132,
#   'duration': 3.204},
#  {'text': "is until they decide\nthey don't want to be here anymore.",
#   'start': 1504.336,
#   'duration': 3.236},
#  {'text': 'As the days passed,', 'start': 1507.606, 'duration': 1.067},
#  {'text': 'TJ was getting more confident\nhe would win it for the boys.',
#   'start': 1508.673,
#   'duration': 2.636},
#  {'text': "I'm just so set on this\nending challenge five",
#   'start': 1511.309,
#   'duration': 3.37},
#  {'text': "I'll be heavily surprised\nif this goes past challenge five.",
#   'start': 1514.679,
#   'duration': 3.003},
#  {'text': 'Everything in my heart,\nsoul, mind is saying challenge five.',
#   'start': 1517.682,
#   'duration': 3.971},
#  {'text': "Even though it's come down to a 1v1,\nboth TJ and Phaedra are still in it",
#   'start': 1521.653,
#   'duration': 4.204},
#  {'text': 'for their fallen soldiers.', 'start': 1525.857, 'duration': 1.068},
#  {'text': "And as for TJ, a victory couldn't\ncome soon enough.",
#   'start': 1528.793,
#   'duration': 2.536},
#  {'text': "I'm going to have\na double portion of rice.",
#   'start': 1531.596,
#   'duration': 3.003},
#  {'text': 'Just make sure that', 'start': 1534.599, 'duration': 1.068},
#  {'text': "I'm going to have a fantastic\nwinning day of day 50.",
#   'start': 1535.7,
#   'duration': 4.138},
#  {'text': 'And now it was time to put all that\ntalk to the test and see',
#   'start': 1539.838,
#   'duration': 3.07},
#  {'text': "if our day 50 challenge\nwill really be in TJ's favor.",
#   'start': 1542.908,
#   'duration': 3.069},
#  {'text': 'Contestants, come on in.\nCome on in.',
#   'start': 1546.011,
#   'duration': 2.903},
#  {'text': "I couldn't make day 50", 'start': 1548.914, 'duration': 1.735},
#  {'text': "because I'm currently\nspending seven days in a cave,",
#   'start': 1550.649,
#   'duration': 2.469},
#  {'text': "- so I'm hologramming in.\n- How's the cave?",
#   'start': 1553.118,
#   'duration': 2.436},
#  {'text': 'Oh my gosh this is insane!', 'start': 1556.821, 'duration': 1.635},
#  {'text': "It's pretty brutal, not going to lie.",
#   'start': 1558.456,
#   'duration': 1.335},
#  {'text': "You guys haven't\nseen each other in a while.",
#   'start': 1559.858,
#   'duration': 1.334},
#  {'text': 'You want to talk?', 'start': 1561.226, 'duration': 1.001},
#  {'text': 'All right.', 'start': 1566.131, 'duration': 0.834},
#  {'text': 'What do you two think\nthe day 50 challenge is?',
#   'start': 1566.965,
#   'duration': 2.402},
#  {'text': 'I have no idea.', 'start': 1569.367, 'duration': 1.202},
#  {'text': 'I see a container\nthat says supplies on it.',
#   'start': 1570.569,
#   'duration': 2.302},
#  {'text': 'For day 50.', 'start': 1572.904, 'duration': 1.301},
#  {'text': "We're going to celebrate.", 'start': 1574.205, 'duration': 1.402},
#  {'text': 'And you both get Feastables.',
#   'start': 1575.607,
#   'duration': 1.969},
#  {'text': '- Okay!\n- Yes!', 'start': 1577.609, 'duration': 1.935},
#  {'text': 'But little did they know,\nthere was a twist coming.',
#   'start': 1579.578,
#   'duration': 2.335},
#  {'text': 'You each get a multipack\nof chocolate.',
#   'start': 1581.913,
#   'duration': 2.069},
#  {'text': "That's so nice. Yeah.", 'start': 1584.316, 'duration': 1.601},
#  {'text': "These are available in Walmart,\nAlbertsons and Kroger's nationwide.",
#   'start': 1585.917,
#   'duration': 3.37},
#  {'text': 'Go buy Feastables\nand try it for yourself.',
#   'start': 1589.321,
#   'duration': 2.302},
#  {'text': "- That's it.\n- You can go back to your camps.",
#   'start': 1591.623,
#   'duration': 1.568},
#  {'text': 'Enjoy your chocolate or save it.',
#   'start': 1593.191,
#   'duration': 1.368},
#  {'text': 'See you on day 60.', 'start': 1595.994, 'duration': 1.602},
#  {'text': '- Are they far away?\n- Yeah.',
#   'start': 1598.029,
#   'duration': 1.902},
#  {'text': "Okay, what they don't know Chandler",
#   'start': 1599.965,
#   'duration': 2.102},
#  {'text': 'is inside one of those\nchocolate bars is a message',
#   'start': 1602.067,
#   'duration': 3.136},
#  {'text': 'that tells them to come back to the\nmiddle to get three days worth of food.',
#   'start': 1605.27,
#   'duration': 4.237},
#  {'text': 'You show the viewers\nthe food.',
#   'start': 1609.541,
#   'duration': 1.835},
#  {'text': "Let's see who finds the message\nfirst.",
#   'start': 1611.376,
#   'duration': 2.069},
#  {'text': 'And wins that food.', 'start': 1613.445, 'duration': 1.535},
#  {'text': "I'll see you in a couple\nof days, Chandler.",
#   'start': 1614.98,
#   'duration': 1.267},
#  {'text': 'I love you.', 'start': 1616.281, 'duration': 1.601},
#  {'text': 'Wait.', 'start': 1617.916, 'duration': 1.101},
#  {'text': 'Say it back.', 'start': 1619.017, 'duration': 1.001},
#  {'text': 'He didn’t say it.', 'start': 1621.219, 'duration': 0.901},
#  {'text': 'Challenge five.', 'start': 1622.821, 'duration': 1.134},
#  {'text': 'We finally got our Feastables.',
#   'start': 1623.955,
#   'duration': 2.102},
#  {'text': 'These are chocolate.', 'start': 1626.057, 'duration': 1.468},
#  {'text': 'Chocolate will melt.', 'start': 1627.525, 'duration': 1.702},
#  {'text': 'So I need to find the best way\nto store these.',
#   'start': 1629.227,
#   'duration': 2.77},
#  {'text': 'I think I might just open another one\nbecause honestly,',
#   'start': 1631.997,
#   'duration': 2.402},
#  {'text': "I know that seems excessive,\nbut it's my win.",
#   'start': 1634.399,
#   'duration': 2.436},
#  {'text': 'I have one square after every meal\nthat should last me',
#   'start': 1636.835,
#   'duration': 3.703},
#  {'text': 'throughout\nthe rest of the competition.',
#   'start': 1640.538,
#   'duration': 1.569},
#  {'text': 'My mental health right now after\nchallenge five is through the roof.',
#   'start': 1642.107,
#   'duration': 3.57},
#  {'text': 'While TJ was feeling confident,\nhe was so strict on rationing',
#   'start': 1645.677,
#   'duration': 3.17},
#  {'text': 'that he barely made\na dent in the Feastables.',
#   'start': 1648.847,
#   'duration': 2.002},
#  {'text': "I feel like I'm better rationing my\nchocolate",
#   'start': 1650.882,
#   'duration': 2.436},
#  {'text': "because that's a better commodity.",
#   'start': 1653.385,
#   'duration': 1.601},
#  {'text': 'So I know I have to save it.', 'start': 1655.02, 'duration': 1.368},
#  {'text': 'And save it he did.', 'start': 1656.421, 'duration': 0.901},
#  {'text': 'TJ went the next three days', 'start': 1657.322, 'duration': 1.468},
#  {'text': 'without touching\na single piece of chocolate.',
#   'start': 1658.79,
#   'duration': 1.902},
#  {'text': 'But then on day 57, he found his\nfavorite flavor.',
#   'start': 1660.725,
#   'duration': 2.937},
#  {'text': 'A peanut butter Feastable.', 'start': 1663.695, 'duration': 2.235},
#  {'text': "Whoa, wait, what?\nThere's something on the back.",
#   'start': 1665.93,
#   'duration': 2.536},
#  {'text': "If you're reading this,\nthere is three days",
#   'start': 1668.466,
#   'duration': 2.436},
#  {'text': 'worth of food on the bridge\nfor the first person to grab it. Good luck',
#   'start': 1670.902,
#   'duration': 3.103},
#  {'text': "Feastable, you'll have to wait.",
#   'start': 1674.039,
#   'duration': 1.134},
#  {'text': "Let's go.", 'start': 1675.173, 'duration': 0.567},
#  {'text': 'Three days worth of food. So much.',
#   'start': 1675.74,
#   'duration': 2.202},
#  {'text': "Let's go.", 'start': 1677.942, 'duration': 0.835},
#  {'text': "I don't see her.", 'start': 1678.777, 'duration': 1.067},
#  {'text': 'This might be a man victory.',
#   'start': 1679.844,
#   'duration': 1.902},
#  {'text': 'Looks to be', 'start': 1683.014, 'duration': 1.468},
#  {'text': 'she already got it.', 'start': 1685.417, 'duration': 1.101},
#  {'text': 'Dang.', 'start': 1687.085, 'duration': 0.968},
#  {'text': 'Phaedra actually beat out TJ because\njust four days ago this happened.',
#   'start': 1688.086,
#   'duration': 4.204},
#  {'text': 'Three days worth of food.', 'start': 1692.524, 'duration': 1.501},
#  {'text': 'It’s still here people.', 'start': 1695.126, 'duration': 1.068},
#  {'text': 'Oh, you guys.', 'start': 1696.194, 'duration': 1.168},
#  {'text': 'It feels really good to win this.',
#   'start': 1697.362,
#   'duration': 1.501},
#  {'text': 'Dang, Phaedra’s not\neven here to gloat about it.',
#   'start': 1699.397,
#   'duration': 2.403},
#  {'text': 'I just feel so sad now.\nI ran for nothing.',
#   'start': 1701.833,
#   'duration': 2.569},
#  {'text': "Feels like\nI've been here for nothing.",
#   'start': 1704.402,
#   'duration': 1.568},
#  {'text': "If TJ isn't careful, that feeling\ncould quickly become reality.",
#   'start': 1705.97,
#   'duration': 3.537},
#  {'text': 'One of these contestants\nwill win their team $500,000,',
#   'start': 1709.507,
#   'duration': 2.944},
#  {'text': 'while the other will have\nspent months in the wilderness',
#   'start': 1712.476,
#   'duration': 2.395},
#  {'text': 'and go home with\nnothing to show for it',
#   'start': 1714.896,
#   'duration': 1.593},
#  {'text': "I can't live off the land because\nit'll take too many calories,",
#   'start': 1716.514,
#   'duration': 3.47},
#  {'text': "and it's not even a guarantee\nevery day.",
#   'start': 1719.984,
#   'duration': 2.003},
#  {'text': 'We just killed the last\nof our egg scramble.',
#   'start': 1722.054,
#   'duration': 2.802},
#  {'text': 'It has been difficult\nfor me to be alone out here.',
#   'start': 1724.856,
#   'duration': 4.905},
#  {'text': 'Every day is hard and is kind of\ntaking its toll on me.',
#   'start': 1729.761,
#   'duration': 2.836},
#  {'text': 'It is night 59.', 'start': 1732.597, 'duration': 2.169},
#  {'text': 'I will run out of rations tomorrow.',
#   'start': 1734.766,
#   'duration': 2.669},
#  {'text': 'I am praying that the prize\nfor tomorrow is more rations.',
#   'start': 1737.435,
#   'duration': 3.971},
#  {'text': "I don't want to give up just yet.",
#   'start': 1741.539,
#   'duration': 1.669},
#  {'text': "It's time for the day 60 challenge.",
#   'start': 1743.208,
#   'duration': 2.068},
#  {'text': 'So you guys met on day 40,', 'start': 1745.276, 'duration': 1.769},
#  {'text': 'Day 50 and once again on day 60.',
#   'start': 1747.045,
#   'duration': 2.836},
#  {'text': "It's the two of you.", 'start': 1749.881, 'duration': 0.901},
#  {'text': 'How is the three days\nof extra rations?',
#   'start': 1750.782,
#   'duration': 1.935},
#  {'text': 'I was going to ask you.\n“How is your candy bars?”',
#   'start': 1752.751,
#   'duration': 2.335},
#  {'text': 'How are you feeling?\nYou got ten days left in you?',
#   'start': 1755.553,
#   'duration': 2.336},
#  {'text': 'Oh, I got ten days left in me.',
#   'start': 1757.889,
#   'duration': 1.869},
#  {'text': 'The day 60 challenge is simple.',
#   'start': 1759.758,
#   'duration': 2.135},
#  {'text': 'Both of you write down\nanything you want.',
#   'start': 1761.893,
#   'duration': 2.102},
#  {'text': 'You’ll then show each\nother what you wrote',
#   'start': 1763.995,
#   'duration': 1.969},
#  {'text': "and if you approve each other's\nitems, you can have both of them.",
#   'start': 1765.964,
#   'duration': 2.936},
#  {'text': 'But if just one of you says no,\nyou both get nothing.',
#   'start': 1768.9,
#   'duration': 3.003},
#  {'text': "You could ask for a lot and there's\na high chance, she says no.",
#   'start': 1771.903,
#   'duration': 2.936},
#  {'text': 'Or you could ask for a little\nand potentially get it.',
#   'start': 1774.839,
#   'duration': 2.403},
#  {'text': '- Do you have what you want written down?\n - I do.',
#   'start': 1777.242,
#   'duration': 1.668},
#  {'text': 'Do you have what you want written down?',
#   'start': 1778.91,
#   'duration': 1.368},
#  {'text': '- Yes.\n- 3, 2, 1, reveal.', 'start': 1780.311, 'duration': 3.237},
#  {'text': 'Phaedra wants an art kit\nand TJ wants a private chef',
#   'start': 1785.183,
#   'duration': 4.471},
#  {'text': 'for seven days, two meals a day,\nfully equipped with spices and food.',
#   'start': 1789.654,
#   'duration': 3.437},
#  {'text': 'Do you approve her\ngetting an art kit?',
#   'start': 1793.124,
#   'duration': 2.102},
#  {'text': 'Oh, yeah.', 'start': 1795.226, 'duration': 0.601},
#  {'text': 'TJ approved you getting an art kit.',
#   'start': 1795.827,
#   'duration': 2.102},
#  {'text': 'So nice.', 'start': 1797.996, 'duration': 1.201},
#  {'text': 'Do you approve his private chef\nfor seven days?',
#   'start': 1799.197,
#   'duration': 3.737},
#  {'text': 'Two meals a day with spices?',
#   'start': 1802.934,
#   'duration': 1.768},
#  {'text': 'I will run out of rations tomorrow.',
#   'start': 1804.702,
#   'duration': 3.137},
#  {'text': 'Oh, man.', 'start': 1810.575, 'duration': 0.734},
#  {'text': "I would love to, but I can't,\nI’m going to have to say no on that.",
#   'start': 1811.309,
#   'duration': 2.636},
#  {'text': 'What?', 'start': 1813.978, 'duration': 0.734},
#  {'text': 'You were too greedy.', 'start': 1816.181, 'duration': 1.067},
#  {'text': 'That was day 60.', 'start': 1817.248, 'duration': 1.302},
#  {'text': "You're free to talk\nas much as you want.",
#   'start': 1818.55,
#   'duration': 1.635},
#  {'text': 'Good luck in the next ten days.',
#   'start': 1820.185,
#   'duration': 1.668},
#  {'text': '- See you on day 70?\n- Yeah.',
#   'start': 1821.853,
#   'duration': 1.902},
#  {'text': '- All right.\n- All right.', 'start': 1823.788, 'duration': 0.634},
#  {'text': '- Bye.\n- See you!', 'start': 1824.489, 'duration': 0.967},
#  {'text': 'For me, the physical aspects of\nthings out here are not the problem.',
#   'start': 1825.49,
#   'duration': 3.57},
#  {'text': "It's the mental things.", 'start': 1829.093, 'duration': 1.102},
#  {'text': 'There goes that idea.', 'start': 1831.429, 'duration': 1.168},
#  {'text': "I had everyone's hopes\nand dreams on my back.",
#   'start': 1832.964,
#   'duration': 3.003},
#  {'text': "I think I'm going to have to put\nthat stone down.",
#   'start': 1836.034,
#   'duration': 3.203},
#  {'text': 'I want to go home so badly.', 'start': 1839.237, 'duration': 1.435},
#  {'text': "I've just been out here for so long.",
#   'start': 1840.672,
#   'duration': 1.668},
#  {'text': 'I just received a radio call saying\nsomeone wanted to leave.',
#   'start': 1845.176,
#   'duration': 3.404},
#  {'text': 'The person\nleaving is waiting in this vehicle.',
#   'start': 1848.613,
#   'duration': 2.536},
#  {'text': 'Bring out the team.', 'start': 1851.149, 'duration': 1.468},
#  {'text': 'Each contestant here is about to\nfind out if their team just won $500,000.',
#   'start': 1852.617,
#   'duration': 5.639},
#  {'text': 'Will it be the men or the women?',
#   'start': 1858.256,
#   'duration': 2.569},
#  {'text': 'The contestant who forfeited\nwill now reveal themselves.',
#   'start': 1860.825,
#   'duration': 3.003},
#  {'text': 'The boys lost and the girls won.',
#   'start': 1866.297,
#   'duration': 2.97},
#  {'text': "We didn't want you guys to go home\nempty handed,",
#   'start': 1870.435,
#   'duration': 1.902},
#  {'text': "so we're going to give each of you\nten grand for at least competing.",
#   'start': 1872.337,
#   'duration': 3.303},
#  {'text': "Phaedra, still alone at the girls\ncamp and has no idea she's just won.",
#   'start': 1876.04,
#   'duration': 3.971},
#  {'text': 'Phaedra, are you here?', 'start': 1881.746, 'duration': 1.468},
#  {'text': "- You're back?\n- Yeah.", 'start': 1883.214, 'duration': 1.168},
#  {'text': 'Come with me real quick.', 'start': 1884.449, 'duration': 0.801},
#  {'text': 'I found this backpack,\nand I was curious if it was yours.',
#   'start': 1885.283,
#   'duration': 2.336},
#  {'text': 'It might be.', 'start': 1887.652, 'duration': 0.734},
#  {'text': 'That was actually a lie.', 'start': 1888.419, 'duration': 0.935},
#  {'text': 'You just won!', 'start': 1889.354, 'duration': 1.001},
#  {'text': 'You did it!', 'start': 1892.056, 'duration': 1.035},
#  {'text': 'I really missed you guys.', 'start': 1894.592, 'duration': 1.435},
#  {'text': '- I thought you guys every day\n- You did it, though.',
#   'start': 1896.027,
#   'duration': 2.002},
#  {'text': '- Yeah.\n- You got it. You did it.',
#   'start': 1898.029,
#   'duration': 2.102},
#  {'text': 'You all just won $100,000 each.',
#   'start': 1900.131,
#   'duration': 2.903},
#  {'text': 'Maybe next time boys.', 'start': 1903.034, 'duration': 1.301}]
